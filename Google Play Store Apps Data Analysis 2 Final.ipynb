# %% [markdown]
# ![share_google_play_logo.png](attachment:share_google_play_logo.png)

# %% [markdown]
# Google Play, also branded as the Google Play Store and formerly Android Market, is a digital distribution service operated and developed by Google. It serves as the official app store for certified devices running on the Android operating system and its derivatives as well as ChromeOS, allowing users to browse and download applications developed with the Android software development kit (SDK) and published through Google. Google Play has also served as a digital media store, offering games, music, books, movies, and television programs be. Content that has been purchased on Google Play Movies & TV and Google Play Books can be accessed on a web browser, and through the Android and iOS apps.
#
# Applications are available through Google Play either free of charge or at a cost. They can be downloaded directly on an Android device through the proprietary Google Play Store mobile app or by deploying the application to a device from the Google Play website. Applications utilizing hardware capabilities of a device can be targeted to users of devices with specific hardware components, such as a motion sensor (for motion-dependent games) or a front-facing camera (for online video calling). The Google Play Store had over 82 billion app downloads in 2016 and reached over 3.5 million apps published in 2017,while after a purge of apps is back to over 3 million.It has been the subject of multiple issues concerning security, in which malicious software has been approved and uploaded to the store and downloaded by users, with varying degrees of severity.
#
# Google Play was launched on March 6, 2012, bringing together Android Market, Google Music, Google Movies and the Google eBookstore under one brand, marking a shift in Google's digital distribution strategy. Following their re-branding, Google has expanded the geographical support for each of the services. Since 2018, Google has gradually sunsetted the Play brand: Play Newsstand was rebranded as Google News in 2018; Play Music was discontinued in favor of YouTube Music in 2020; and Play Movies & TV was rebranded as Google TV in 2021.

# %% [markdown]
# # GOOGLE PLAY STORE DATA ANALYSIS

# %% [markdown]
# # Lets , start with importing useful Libraries

# %%
import pandas as pd #For Framing the data. 
import numpy as np #For Staistical Operations.

# %%
from matplotlib import pyplot as plt # For Visuallization of Graphs
import seaborn as sns # For Visualization Of Graphs

# %%
import plotly.express as px # For Visualization Of Graphs.
import cufflinks as cf # For Visualization Of Graphs.
cf.set_config_file(offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %%
import warnings #For ignoring useless warnings. 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Creating a DataFrame ------------->

# %%
df_GooglePlay = pd.read_csv('googleplaystore.csv')

# %%
df_GooglePlay.shape
# Out:
# (10841, 13)

# %%
df_GooglePlay
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_GooglePlay.drop_duplicates(inplace=True)

# %%
df_GooglePlay
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## Checking N/A values ------------>

# %%
df_GooglePlay.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ### ['Rating '] has too many N/A values . so , we have to handle it

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_GooglePlay.isnull(), yticklabels = False, cmap = 'viridis', cbar = False)
# Out:
# <AxesSubplot:>

# %%
def missingvalue():
    gpm = pd.DataFrame(index=df_GooglePlay.columns)
    gpm['data_type'] = df_GooglePlay.dtypes
    gpm['null_count'] = df_GooglePlay.isnull().sum()
    gpm['unique_count'] = df_GooglePlay.nunique()
    return gpm

# %%
missingvalue()
# Out:
#                data_type  null_count  unique_count
# App               object           0          9660
# Category          object           0            34
# Rating           float64        1465            40
# Reviews           object           0          6002
# Size              object           0           462
# Installs          object           0            22
# Type              object           1             3
# Price             object           0            93
# Content Rating    object           1             6
# Genres            object           0           120
# Last Updated      object           0          1378
# Current Ver       object           8          2832
# Android Ver       object           3            33

# %%
rating_mvh = df_GooglePlay['Rating'].mode()

# %% [markdown]
# ## Most common value in 'Rating ' feature

# %%
rating_mvh
# Out:
# 0    4.4
# Name: Rating, dtype: float64

# %%
rating_mvh[0]
# Out:
# 4.4

# %% [markdown]
# ## Replace all N/A value in 'Rating ' feature with MODE = 4.4

# %%
df_GooglePlay['Rating'].fillna(value=rating_mvh[0], inplace = True)

# %% [markdown]
# ## N/A count in 'Rating' feature is zero

# %%
df_GooglePlay.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
 missingvalue()
# Out:
#                data_type  null_count  unique_count
# App               object           0          9660
# Category          object           0            34
# Rating           float64           0            40
# Reviews           object           0          6002
# Size              object           0           462
# Installs          object           0            22
# Type              object           1             3
# Price             object           0            93
# Content Rating    object           1             6
# Genres            object           0           120
# Last Updated      object           0          1378
# Current Ver       object           8          2832
# Android Ver       object           3            33

# %% [markdown]
# ### Droping a Row which have a Null value in ['Content Rating'] feature

# %%
df_GooglePlay.dropna(subset = ['Content Rating'], inplace=True)

# %%
missingvalue()
# Out:
#                data_type  null_count  unique_count
# App               object           0          9659
# Category          object           0            33
# Rating           float64           0            39
# Reviews           object           0          6001
# Size              object           0           461
# Installs          object           0            21
# Type              object           1             2
# Price             object           0            92
# Content Rating    object           0             6
# Genres            object           0           119
# Last Updated      object           0          1377
# Current Ver       object           8          2831
# Android Ver       object           2            33

# %%
df_GooglePlay[df_GooglePlay['Type'].isnull()]
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     4.4       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %% [markdown]
# ### Most common value of [Type] feature is 'Free'

# %%
df_GooglePlay['Type'].mode()
# Out:
# 0    Free
# Name: Type, dtype: object

# %% [markdown]
# ### Filling NaN with 'Free' in ['Type'] feature

# %%
df_GooglePlay['Type'].fillna("Free", inplace = True)

# %% [markdown]
# ### Dataset containing N/A values in  ['Current Ver'] feature

# %%
df_GooglePlay[df_GooglePlay['Current Ver'].isnull()]
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     4.4       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     4.4      44
# 7730                            UFO-CQ                TOOLS     4.4       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     4.4       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# ...

# %%
df_GooglePlay.drop(['Current Ver'], axis=1, inplace=True)

# %%
df_GooglePlay
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
missingvalue()
# Out:
#                data_type  null_count  unique_count
# App               object           0          9659
# Category          object           0            33
# Rating           float64           0            39
# Reviews           object           0          6001
# Size              object           0           461
# Installs          object           0            21
# Type              object           0             2
# Price             object           0            92
# Content Rating    object           0             6
# Genres            object           0           119
# Last Updated      object           0          1377
# Android Ver       object           2            33

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_GooglePlay.isnull(), yticklabels = False, cmap = 'viridis', cbar = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Size feature has a data type that is object , so we have to convert it into float

# %%
df_GooglePlay['Size'] = df_GooglePlay.Size.apply(lambda x: x.strip('+'))

# %%
df_GooglePlay['Size'] = df_GooglePlay.Size.apply(lambda x: x.replace(',', ''))

# %%
df_GooglePlay['Size'] = df_GooglePlay.Size.apply(lambda x: x.replace('M', 'e+6'))

# %%
df_GooglePlay['Size'] = df_GooglePlay.Size.apply(lambda x: x.replace('k', 'e+3'))

# %%
df_GooglePlay['Size'] = df_GooglePlay.Size.replace('Varies with device', np.NaN)

# %%
df_GooglePlay['Size'] = pd.to_numeric(df_GooglePlay['Size'])

# %%
missingvalue()
# Out:
#                data_type  null_count  unique_count
# App               object           0          9659
# Category          object           0            33
# Rating           float64           0            39
# Reviews           object           0          6001
# Size             float64        1526           459
# Installs          object           0            21
# Type              object           0             2
# Price             object           0            92
# Content Rating    object           0             6
# Genres            object           0           119
# Last Updated      object           0          1377
# Android Ver       object           2            33

# %% [markdown]
# ## now, size feature has 1526 N/A values

# %%
df_GooglePlay.dropna(subset = ['Size'], inplace=True)

# %%
missingvalue()
# Out:
#                data_type  null_count  unique_count
# App               object           0          8434
# Category          object           0            33
# Rating           float64           0            39
# Reviews           object           0          4680
# Size             float64           0           459
# Installs          object           0            20
# Type              object           0             2
# Price             object           0            87
# Content Rating    object           0             6
# Genres            object           0           116
# Last Updated      object           0          1358
# Android Ver       object           2            33

# %% [markdown]
# ## ['Installs'] feature is in object data type which was converted in to int data type

# %%
df_GooglePlay['Installs'] = df_GooglePlay.Installs.apply(lambda x: x.strip('+'))

# %%
df_GooglePlay['Installs'] = df_GooglePlay.Installs.apply(lambda x: x.replace(',', ''))

# %%
df_GooglePlay['Installs'] = pd.to_numeric(df_GooglePlay['Installs'])

# %%
missingvalue()
# Out:
#                data_type  null_count  unique_count
# App               object           0          8434
# Category          object           0            33
# Rating           float64           0            39
# Reviews           object           0          4680
# Size             float64           0           459
# Installs           int64           0            20
# Type              object           0             2
# Price             object           0            87
# Content Rating    object           0             6
# Genres            object           0           116
# Last Updated      object           0          1358
# Android Ver       object           2            33

# %%
df_GooglePlay['Price'].value_counts()
# Out:
# 0          8140
# $0.99       143
# $2.99       111
# $1.99        66
# $4.99        63
#            ...
# $18.99        1
# $389.99       1
# $19.90        1
# $1.75         1
# $1.04         1
# Name: Price, Length: 87, dtype: int64

# %%
df_GooglePlay['Price'] = df_GooglePlay.Price.apply(lambda x: x.strip('$'))

# %%
df_GooglePlay['Price'].value_counts()
# Out:
# 0         8140
# 0.99       143
# 2.99       111
# 1.99        66
# 4.99        63
#           ...
# 18.99        1
# 389.99       1
# 19.90        1
# 1.75         1
# 1.04         1
# Name: Price, Length: 87, dtype: int64

# %% [markdown]
# ## Now , we have to convert data type  of  ['Price'] feature to int

# %%
df_GooglePlay['Price'] = pd.to_numeric(df_GooglePlay['Price'])

# %%
missingvalue()
# Out:
#                data_type  null_count  unique_count
# App               object           0          8434
# Category          object           0            33
# Rating           float64           0            39
# Reviews           object           0          4680
# Size             float64           0           459
# Installs           int64           0            20
# Type              object           0             2
# Price            float64           0            87
# Content Rating    object           0             6
# Genres            object           0           116
# Last Updated      object           0          1358
# Android Ver       object           2            33

# %%
df_GooglePlay.shape
# Out:
# (8831, 12)

# %%
df_GooglePlay
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#        Rating Reviews        Size  Installs  Type  Price Content Rating  \
# ...

# %%
df_GooglePlay.to_csv("Cleaned_Data_Google_Play_Store_13_Col.csv")

# %%
df_GooglePlay.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size              float64
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Android Ver        object
# dtype: object

# %% [markdown]
# ## ['Reviews'] feature is in object data type which was converted into int data type.

# %%
df_GooglePlay['Reviews'] = df_GooglePlay.Reviews.apply(lambda x: x.replace('M', 'e+6'))

# %%
df_GooglePlay['Reviews'] = pd.to_numeric(df_GooglePlay['Reviews'])

# %%
df_GooglePlay.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8831 entries, 0 to 10840
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8831 non-null   object
#  1   Category        8831 non-null   object
#  2   Rating          8831 non-null   float64
#  3   Reviews         8831 non-null   int64
#  4   Size            8831 non-null   float64
#  5   Installs        8831 non-null   int64
#  6   Type            8831 non-null   object
#  7   Price           8831 non-null   float64
#  8   Content Rating  8831 non-null   object
#  9   Genres          8831 non-null   object
#  10  Last Updated    8831 non-null   object
#  11  Android Ver     8829 non-null   object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 896.9+ KB

# %% [markdown]
# ## ['Price'] has too many unique values

# %%
df_GooglePlay.groupby('Price')['Price'].count()
# Out:
# Price
# 0.00      8140
# 0.99       143
# 1.00         3
# 1.04         1
# 1.20         1
#           ...
# 379.99       1
# 389.99       1
# 394.99       1
# 399.99      12
# 400.00       1
# Name: Price, Length: 87, dtype: int64

# %%
df_GooglePlay['Price'].unique()
# Out:
# array([  0.  ,   4.99,   6.99,   1.49,   2.99,   3.99,   7.99,   5.99,
#          1.99,   9.99,   0.99,   9.  ,   5.49,  10.  ,  24.99,  11.99,
#         79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,   3.49,  10.99,
#          7.49,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,   2.49,
#          4.49,   1.7 ,   2.  ,   3.88,  25.99, 399.99,  17.99, 400.  ,
#          3.02,   1.76,   4.84,   4.77,   1.61,   1.59,   6.49,   1.29,
#          5.  ,  13.99, 299.99, 379.99,  37.99,  18.99, 389.99,  19.9 ,
#          8.49,   1.75,  14.  ,   4.85,  46.99, 109.99, 154.99,   3.08,
#          2.59,   4.8 ,   8.99,   1.96,  19.4 ,  15.46,   3.04,   4.29,
#          2.6 ,   3.28,   4.6 ,  28.99,   2.9 ,   1.97, 200.  ,  89.99,
#          2.56,  30.99,   3.61, 394.99,   1.26,   1.2 ,   1.04])

# %% [markdown]
# ## Rounding of unique values to 0 decimal values

# %%
df_GooglePlay['Price']=df_GooglePlay['Price'].round(0)

# %%
df_GooglePlay.groupby('Price')['Price'].count()
# Out:
# Price
# 0.0      8140
# 1.0       193
# 2.0        97
# 3.0       125
# 4.0        58
# 5.0        73
# 6.0        28
# 7.0        10
# 8.0         9
# 9.0         4
# 10.0       21
# 11.0        2
# 12.0        2
# 13.0        3
# 14.0        3
# 15.0       10
# 16.0        1
# 17.0        2
# 18.0        2
# 19.0        2
# 20.0        6
# 25.0        4
# 26.0        1
# 29.0        1
# 30.0        5
# 31.0        1
# 34.0        1
# 38.0        1
# 40.0        2
# 47.0        1
# 75.0        1
# 80.0        1
# 90.0        1
# 110.0       1
# 155.0       1
# 200.0       1
# 300.0       1
# 380.0       1
# 390.0       1
# 395.0       1
# 400.0      13
# Name: Price, dtype: int64

# %%
df_GooglePlay['Price'].unique()
# Out:
# array([  0.,   5.,   7.,   1.,   3.,   4.,   8.,   6.,   2.,  10.,   9.,
#         25.,  12.,  80.,  17.,  15.,  30.,  13.,  11.,  20.,  16.,  34.,
#         75.,  40.,  26., 400.,  18.,  14., 300., 380.,  38.,  19., 390.,
#         47., 110., 155.,  29., 200.,  90.,  31., 395.])

# %%
data=df_GooglePlay

# %%
data
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#        Rating  Reviews        Size  Installs  Type  Price Content Rating  \
# ...

# %%
data.to_csv("cleaned_data.csv")

# %%
data.describe()
# Out:
#             Rating       Reviews          Size      Installs        Price
# count  8831.000000  8.831000e+03  8.831000e+03  8.831000e+03  8831.000000
# mean      4.207745  2.343613e+05  2.128779e+07  6.577887e+06     1.171555
# std       0.510935  1.601932e+06  2.254025e+07  4.255139e+07    17.620567
# min       1.000000  0.000000e+00  8.500000e+03  0.000000e+00     0.000000
# 25%       4.000000  2.000000e+01  4.700000e+06  1.000000e+03     0.000000
# 50%       4.400000  6.540000e+02  1.300000e+07  5.000000e+04     0.000000
# 75%       4.500000  2.254800e+04  2.900000e+07  1.000000e+06     0.000000
# max       5.000000  4.489389e+07  1.000000e+08  1.000000e+09   400.000000

# %%
data.corr()
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.068778  0.052707  0.042486 -0.018702
# Reviews   0.068778  1.000000  0.237893  0.633612 -0.009662
# Size      0.052707  0.237893  1.000000  0.168872 -0.023696
# Installs  0.042486  0.633612  0.168872  1.000000 -0.010248
# Price    -0.018702 -0.009662 -0.023696 -0.010248  1.000000

# %%
data.shape
# Out:
# (8831, 12)

# %%
data.dropna(inplace=True)

# %% [markdown]
# ### Cleaning of data is completed !

# %% [markdown]
# # Observation -1

# %%
data['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
df_1 = data[(data['Type']=='Free')  & (data['Reviews']<4.0)]

# %%
df_1
# Out:
#                                         App             Category  Rating  \
# 180     SH-02J Owner's Manual (Android 8.0)  BOOKS_AND_REFERENCE     4.4
# 610                       Random Video Chat               DATING     4.4
# 611                             MouseMingle               DATING     2.7
# 613    Random Video Chat App With Strangers               DATING     4.4
# 615                            Awake Dating               DATING     5.0
# ...                                     ...                  ...     ...
# 10816                    FieldBi FR Offline             BUSINESS     4.4
# 10822                             PLMGSS FR         PRODUCTIVITY     4.4
# 10823                          List iptv FR        VIDEO_PLAYERS     4.4
# 10835                              FR Forms             BUSINESS     4.4
# 10838                Parkinson Exercices FR              MEDICAL     4.4
#
#        Reviews        Size  Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ## There are 11% of apps present in dataset which are Free and having rating greater than 4.0,It means that,these are  Economical apps

# %% [markdown]
# ## 1051 out of 9145(1059/9145=0.11)

# %% [markdown]
# # ------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Observation -2:

# %%
d=pd.DataFrame(df_1.groupby('Category')['Category'].count())

# %%
d
# Out:
#                      Category
# Category
# ART_AND_DESIGN              2
# AUTO_AND_VEHICLES           9
# BEAUTY                      6
# BOOKS_AND_REFERENCE        22
# BUSINESS                  145
# COMICS                      1
# COMMUNICATION              37
# DATING                     32
# EVENTS                     11
# FAMILY                    150
# FINANCE                    30
# FOOD_AND_DRINK             15
# GAME                       25
# HEALTH_AND_FITNESS         37
# HOUSE_AND_HOME              6
# LIBRARIES_AND_DEMO          5
# LIFESTYLE                  64
# MAPS_AND_NAVIGATION         7
# MEDICAL                   103
# NEWS_AND_MAGAZINES         31
# PARENTING                   1
# PERSONALIZATION            47
# PHOTOGRAPHY                17
# PRODUCTIVITY               53
# SHOPPING                   20
# SOCIAL                     23
# SPORTS                     44
# TOOLS                      73
# TRAVEL_AND_LOCAL           21
# ...

# %%
d.columns=["a"]

# %%
plt.figure(figsize=(20,15))
sns.barplot(x=d.sort_values(by='a' , ascending=False)["a"].index,y=d.sort_values(by='a' , ascending=False)["a"] , palette=["#4285f4","#ea4335","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Family category has most of the Apps  followed by Business Category

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Observation-3

# %%
data_family=data[data['Category']=='FAMILY']

# %%
data_family
# Out:
#                                     App Category  Rating  Reviews        Size  \
# 2015                         Candy Bomb   FAMILY     4.4    42145  20000000.0
# 2016                             ROBLOX   FAMILY     4.5  4449910  67000000.0
# 2017       Jewels Crush- Match 3 Puzzle   FAMILY     4.4    14774  19000000.0
# 2018                   Coloring & Learn   FAMILY     4.4    12753  51000000.0
# 2019                            Mahjong   FAMILY     4.5    33983  22000000.0
# ...                                 ...      ...     ...      ...         ...
# 10821                           Poop FR   FAMILY     4.4        6   2500000.0
# 10827                Fr Agnel Ambarnath   FAMILY     4.2      117  13000000.0
# 10834                     FR Calculator   FAMILY     4.0        7   2600000.0
# 10836                  Sya9a Maroc - FR   FAMILY     4.5       38  53000000.0
# 10837  Fr. Mike Schmitz Audio Teachings   FAMILY     5.0        4   3600000.0
#
# ...

# %%
series=data_family.groupby('App')['Installs'].sum()

# %%
series=series.sort_values(ascending=False)

# %%
series[:10]
# Out:
# App
# Pou                        500000000
# Candy Crush Saga           500000000
# ROBLOX                     400000000
# Toca Kitchen 2             150000000
# Frozen Free Fall           150000000
# Turbo FAST                 100000000
# My Talking Angela          100000000
# Plants vs. Zombies FREE    100000000
# Tom Loves Angela           100000000
# Where's My Water? Free     100000000
# Name: Installs, dtype: int64

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Top 10 Apps in Family category according to number of Installs

# %% [markdown]
# 1. Pou
# 2. Candy Crush Saga
# 3. ROBLOX
# 4. Toca Kitchen 2
# 5. Frozen Free Fall
# 6. Turbo FAST
# 7. My Talking Angela
# 8. Plants vs. Zombies FREE
# 9. Tom Loves Angela
# 10. Where's My Water? Free

# %%
sns.lineplot(x='Price' , y='Installs' , data=data)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Installs'>

# %%
data['Price'].value_counts()
# Out:
# 0.0      8139
# 1.0       192
# 3.0       125
# 2.0        97
# 5.0        73
# 4.0        58
# 6.0        28
# 10.0       21
# 400.0      13
# 15.0       10
# 7.0        10
# 8.0         9
# 20.0        6
# 30.0        5
# 25.0        4
# 9.0         4
# 14.0        3
# 13.0        3
# 17.0        2
# 18.0        2
# 40.0        2
# 12.0        2
# 11.0        2
# 19.0        2
# 90.0        1
# 200.0       1
# 31.0        1
# 29.0        1
# 390.0       1
# 155.0       1
# 110.0       1
# 47.0        1
# 16.0        1
# 38.0        1
# 380.0       1
# 300.0       1
# 26.0        1
# 75.0        1
# 34.0        1
# 80.0        1
# 395.0       1
# Name: Price, dtype: int64

# %%
sns.boxplot(data['Price'])
# Out:
# <AxesSubplot:xlabel='Price'>

# %% [markdown]
# # Observation : 4

# %%
data
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#        Rating  Reviews        Size  Installs  Type  Price Content Rating  \
# ...

# %%
sns.jointplot(data.Installs , data.Size)

# %%
data.sort_values(by='Installs' , ascending=False).head(5)
# Out:
#                  App            Category  Rating   Reviews        Size  \
# 1700  Subway Surfers                GAME     4.5  27723193  76000000.0
# 3736     Google News  NEWS_AND_MAGAZINES     3.9    877635  13000000.0
# 9844     Google News  NEWS_AND_MAGAZINES     3.9    878065  13000000.0
# 3816     Google News  NEWS_AND_MAGAZINES     3.9    877643  13000000.0
# 1872  Subway Surfers                GAME     4.5  27725352  76000000.0
#
#         Installs  Type  Price Content Rating            Genres  \
# 1700  1000000000  Free    0.0   Everyone 10+            Arcade
# 3736  1000000000  Free    0.0           Teen  News & Magazines
# 9844  1000000000  Free    0.0           Teen  News & Magazines
# 3816  1000000000  Free    0.0           Teen  News & Magazines
# 1872  1000000000  Free    0.0   Everyone 10+            Arcade
#
#         Last Updated Android Ver
# 1700   July 12, 2018  4.1 and up
# 3736  August 1, 2018  4.4 and up
# 9844  August 1, 2018  4.4 and up
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x=data.sort_values(by="Installs",ascending=False)["Category"] , y=data.sort_values(by="Installs",ascending=False)['Installs'] , palette=["#4285f4","#ea4335","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853"] )
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Almost 30% of Total installs are of category - GAME. This Indicates that most of the audiance  loves to play games.

# %% [markdown]
# # Observation-5

# %%
# sum of no. of installs of category(game , news_and_magazines , communication)
installs_of_three_category=data.groupby('Category')['Installs'].sum()['GAME']+ data.groupby('Category')['Installs'].sum()['NEWS_AND_MAGAZINES']+ data.groupby('Category')['Installs'].sum()['COMMUNICATION']

# %%
# Total number of installs
Total_number_of_installs=data['Installs'].sum()

# %%
installs_of_three_category/Total_number_of_installs
# Out:
# 0.5741936156932415

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### 57% of total Installs is gone under only three Category('GAME' ,'NEWS_AND_MAGAZINES', 'COMMUNICATION' )

# %% [markdown]
# # Observation-6

# %%
# adjust the indexing
data=pd.DataFrame(data=data , index=np.arange(9144))

# %%
data
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 9139                                        DZ Register    PRODUCTIVITY
# 9140                                     EA SPORTS UFC®          SPORTS
# 9141                         NBA LIVE Mobile Basketball          SPORTS
# 9142                          Need for Speed™ No Limits            GAME
# 9143                                      Real Racing 3          FAMILY
#
#       Rating    Reviews        Size    Installs  Type  Price Content Rating  \
# ...

# %%
data['Reviews*Rating']=data['Reviews']*data['Rating']

# %%
data
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 9139                                        DZ Register    PRODUCTIVITY
# 9140                                     EA SPORTS UFC®          SPORTS
# 9141                         NBA LIVE Mobile Basketball          SPORTS
# 9142                          Need for Speed™ No Limits            GAME
# 9143                                      Real Racing 3          FAMILY
#
#       Rating    Reviews        Size    Installs  Type  Price Content Rating  \
# ...

# %%
series=data.groupby('App')['Reviews*Rating'].sum()

# %%
series1=series.sort_values(ascending=False)

# %%
top_apps=series1[:10]

# %%
top_apps
# Out:
# App
# Subway Surfers                                 623729727.0
# Clash of Clans                                 619468466.8
# Candy Crush Saga                               493391764.8
# 8 Ball Pool                                    447237891.0
# Clash Royale                                   425639370.8
# Pou                                            180341144.3
# ROBLOX                                         180172705.5
# My Talking Angela                              177855628.5
# Temple Run 2                                   174545569.9
# UC Browser - Fast Download Private & Secure    159424974.0
# Name: Reviews*Rating, dtype: float64

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Here are the top 10 APPS Of Google Play Store according to crowd's interactions

# %% [markdown]
# 1.Subway Surfers
# 2.Clash of Clans
# 3.Candy Crush Saga
# 4.8 Ball Pool
# 5.Clash Royale
# 6.Pou
# 7.ROBLOX
# 8.My Talking Angela
# 9.Temple Run 2
# 10.UC Browser - Fast Download Private & Secure

# %% [markdown]
# # Observation-7

# %%
series=data.groupby('App')['Installs'].sum()

# %%
series1=series.sort_values(ascending=False)

# %%
series1[:10]
# Out:
# App
# Subway Surfers                                 5.000000e+09
# Temple Run 2                                   2.500000e+09
# Candy Crush Saga                               2.500000e+09
# Google News                                    2.000000e+09
# Pou                                            2.000000e+09
# Dropbox                                        1.500000e+09
# imo free video calls and chat                  1.000000e+09
# UC Browser - Fast Download Private & Secure    1.000000e+09
# SHAREit - Transfer & Share                     1.000000e+09
# ROBLOX                                         9.000000e+08
# Name: Installs, dtype: float64

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Here, Is the top 10 APPS Of Google Play Store according to number of Installs

# %% [markdown]
# 1.Subway Surfers
# 2.Candy Crush Saga
# 3.Google News
# 4.Temple Run 2
# 5.imo free video calls and chat
# 6.Pou
# 7.Dropbox
# 8.UC Browser - Fast Download Private & Secure
# 9.SHAREit - Transfer & Share
# 10.ROBLOX

# %% [markdown]
# # Observation -8

# %%
data['Reviews/Installs']=data['Reviews']/data['Installs']

# %%
data_apps=data[(data['Installs']>10000) & (data['Reviews/Installs']>0.1) & (data['Rating']>4.0)]

# %%
series=data_apps.groupby('App')['Installs'].sum()

# %%
series1=series.sort_values(ascending=False)

# %%
series1[:10]
# Out:
# App
# 8 Ball Pool                                           700000000.0
# Clash Royale                                          400000000.0
# Clash of Clans                                        300000000.0
# Cache Cleaner-DU Speed Booster (booster & cleaner)    200000000.0
# Shadow Fight 2                                        200000000.0
# Pokémon GO                                            200000000.0
# DU Battery Saver - Battery Charger & Battery Life     100000000.0
# Yes day                                               100000000.0
# Hay Day                                               100000000.0
# Boom Beach                                             50000000.0
# Name: Installs, dtype: float64

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Top 10 Apps with  10 reviews per 100  installs with Rating more than 4.0

# %% [markdown]
# # Observation -9

# %%
data[(data['Installs']>10000) & (data['Reviews/Installs']>0.4) & (data['Rating']>4.0)]
# Out:
#                              App Category  Rating     Reviews        Size  \
# 1670              Clash of Clans     GAME     4.6  44891723.0  98000000.0
# 1879              Clash of Clans     GAME     4.6  44893888.0  98000000.0
# 3986              Clash of Clans   FAMILY     4.6  44881447.0  98000000.0
# 4556               Day R Premium   FAMILY     4.8     51068.0  57000000.0
# 7610  Ski Safari: Adventure Time   FAMILY     4.5     48754.0   9300000.0
#
#          Installs  Type  Price Content Rating                     Genres  \
# 1670  100000000.0  Free    0.0   Everyone 10+                   Strategy
# 1879  100000000.0  Free    0.0   Everyone 10+                   Strategy
# 3986  100000000.0  Free    0.0   Everyone 10+                   Strategy
# 4556     100000.0  Paid    5.0           Teen               Role Playing
# 7610     100000.0  Paid    1.0       Everyone  Arcade;Action & Adventure
#
#          Last Updated   Android Ver  Reviews*Rating  Reviews/Installs
# ...

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### There  are only 3 Apps  with 40 reviews per 100 installs having Rating more than 4.0: one from GAME category and 2 from Family category
# ### This Indicates that people are more interactive towards these apps

# %% [markdown]
# # Observation- 10

# %%
data.groupby('Category')['Installs'].sum()
# Out:
# Category
# ART_AND_DESIGN         9.933810e+07
# AUTO_AND_VEHICLES      4.375198e+07
# BEAUTY                 1.359185e+07
# BOOKS_AND_REFERENCE    1.164403e+08
# BUSINESS               3.798852e+08
# COMICS                 1.757615e+07
# COMMUNICATION          3.309356e+09
# DATING                 1.051011e+08
# EDUCATION              2.083020e+08
# ENTERTAINMENT          7.489600e+08
# EVENTS                 1.067091e+07
# FAMILY                 5.852037e+09
# FINANCE                3.075947e+08
# FOOD_AND_DRINK         1.714287e+08
# GAME                   2.595677e+10
# HEALTH_AND_FITNESS     7.723216e+08
# HOUSE_AND_HOME         5.061216e+07
# LIBRARIES_AND_DEMO     5.079541e+07
# LIFESTYLE              4.212092e+08
# MAPS_AND_NAVIGATION    1.637832e+08
# MEDICAL                3.518226e+07
# NEWS_AND_MAGAZINES     2.201954e+09
# PARENTING              2.397001e+07
# PERSONALIZATION        9.674525e+08
# PHOTOGRAPHY            2.350669e+09
# PRODUCTIVITY           2.690506e+09
# ...

# %%
data['Gaming category app'] = data['Category'] =='Game'
category_type_installs = data.groupby(['Category','Type'])[['Installs']].sum().reset_index()
category_type_installs['Log_installs'] = np.log10(category_type_installs["Installs"])
plt.figure(figsize=(18,9))
plt.xticks(rotation=65, fontsize=9)
plt.xlabel('Category')
plt.ylabel('Installs(base10)')
plt.title('Number of installs(base10) type wise according to Category')
sns.barplot("Category","Log_installs", hue='Type', data=category_type_installs ,palette=["#4285f4","#ea4335","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853"] );
plt.show()

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Highest number of Installs are of GAME category (for both Free and Paid)  followed by Communication & News_and_magzines

# %% [markdown]
# # Observation-11

# %%
data.groupby('Category')['Category'].count()
# Out:
# Category
# ART_AND_DESIGN           62
# AUTO_AND_VEHICLES        64
# BEAUTY                   44
# BOOKS_AND_REFERENCE     151
# BUSINESS                277
# COMICS                   50
# COMMUNICATION           207
# DATING                  176
# EDUCATION                96
# ENTERTAINMENT            67
# EVENTS                   49
# FAMILY                 1382
# FINANCE                 236
# FOOD_AND_DRINK           93
# GAME                    835
# HEALTH_AND_FITNESS      217
# HOUSE_AND_HOME           57
# LIBRARIES_AND_DEMO       78
# LIFESTYLE               281
# MAPS_AND_NAVIGATION      89
# MEDICAL                 359
# NEWS_AND_MAGAZINES      170
# PARENTING                53
# PERSONALIZATION         291
# PHOTOGRAPHY             223
# PRODUCTIVITY            243
# SHOPPING                173
# SOCIAL                  154
# SPORTS                  190
# TOOLS                   596
# TRAVEL_AND_LOCAL        140
# VIDEO_PLAYERS           115
# ...

# %%
app_count = data.groupby(["Category", "Type"])[['App']].count().reset_index().rename(columns={'App':'Count', 'index':'App'})
df_app_count = app_count.pivot('Category','Type','Count').fillna(0).reset_index()
df_app_count.set_index('Category').plot(kind='bar', stacked=True, figsize=(18,9),)
plt.xlabel('Category', fontsize=15)
plt.ylabel('Count',fontsize=15)
plt.title("Count of application in each category according to types")
plt.show()

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Family category has the most number of free and paid apps followed by games category

# %% [markdown]
# # Observation -12

# %%
data
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 9139                                        DZ Register    PRODUCTIVITY
# 9140                                     EA SPORTS UFC®          SPORTS
# 9141                         NBA LIVE Mobile Basketball          SPORTS
# 9142                          Need for Speed™ No Limits            GAME
# 9143                                      Real Racing 3          FAMILY
#
#       Rating    Reviews        Size    Installs  Type  Price Content Rating  \
# ...

# %%
data[data['Size']<5000000]
# Out:
#                                                   App        Category  Rating  \
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 15                    Learn To Draw Kawaii Characters  ART_AND_DESIGN     3.2
# 22            Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN     4.7
# 28                              Pencil Sketch Drawing  ART_AND_DESIGN     3.9
# ...                                               ...             ...     ...
# 9131                                      dekoreko-dz        SHOPPING     4.4
# 9132  ChangeDA - Cours du DZD sur le marché parallèle         FINANCE     4.4
# 9134                    Tunisian Dinar: Exchange rate         FINANCE     4.5
# 9135                            love sms good morning   COMMUNICATION     4.2
# 9138                                       DZ Blagues          FAMILY     4.2
#
# ...

# %%
1852/9145
# Out:
# 0.20251503553854566

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### 20% of Apps (1852) which are available on Google PlayStore are  of size less than 5MB

# %% [markdown]
# # Observation-13

# %%
plt.figure(figsize=(12,8))
sns.countplot(data['Content Rating'] , palette=["#4285f4","#ea4335","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853"])
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='count'>

# %%
data_=data[(data['Type']=='Free') & (data['Size']<500000) ]

# %%
data_
# Out:
#                                 App            Category  Rating   Reviews  \
# 58                Restart Navigator   AUTO_AND_VEHICLES     4.0    1403.0
# 209                 Plugin:AOT v5.0            BUSINESS     3.1    4034.0
# 384   Hangouts Dialer - Call Phones       COMMUNICATION     4.0  122498.0
# 450                     Caller ID +       COMMUNICATION     4.0    9498.0
# 1019             Mummatikabalkuragi              EVENTS     4.9      69.0
# ...                             ...                 ...     ...       ...
# 8586                        DN Sync  NEWS_AND_MAGAZINES     4.1      56.0
# 8650              To-Do List Widget        PRODUCTIVITY     3.9    7801.0
# 8911      Modern: DU Launcher Theme     PERSONALIZATION     4.2     868.0
# 8913       Night: DU Launcher Theme     PERSONALIZATION     4.3    1419.0
# 9017   DW Missed call cleaner patch               TOOLS     3.9      65.0
#
#           Size    Installs  Type  Price Content Rating            Genres  \
# ...

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### 105 Apps are available on play store which are Free and having size less than 5MB

# %% [markdown]
# # Observation -14

# %%
series=data_.groupby('App')['Installs'].sum()

# %%
series1=series.sort_values(ascending=False)

# %%
series1[:10]
# Out:
# App
# Satellite Director               10000000.0
# Hangouts Dialer - Call Phones    10000000.0
# Aviary Effects: Classic           5000000.0
# Wifi Connect Library              5000000.0
# Bubble                            5000000.0
# BTNotification                    5000000.0
# Caller ID +                       1000000.0
# [ROOT] X Privacy Installer        1000000.0
# To-Do List Widget                 1000000.0
# Tiny Call Confirm                 1000000.0
# Name: Installs, dtype: float64

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ###  Here  is the list of top 10 Apps which are Free and having size less than 5MB According to number of Installs

# %% [markdown]
# 1. Satellite Director
# 2. Hangouts Dialer - Call Phones
# 3. Aviary Effects: Classic
# 4. Wifi Connect Library
# 5. Bubble
# 6. BTNotification
# 7. Caller ID +
# 8. [ROOT] X Privacy Installer
# 9. To-Do List Widget
# 10.Tiny Call Confirm

# %% [markdown]
# # Observation-15

# %%
a=data[data['Size']<5000000]
top_ten=a[a["Type"]=="Free"].sort_values(by="Installs",ascending=False).head(11)

# %%
top_ten
# Out:
#                                               App         Category  Rating  \
# 3261                           Samsung Calculator            TOOLS     4.4
# 4633  UC Browser Mini -Tiny Fast Private & Secure    COMMUNICATION     4.4
# 366   UC Browser Mini -Tiny Fast Private & Secure    COMMUNICATION     4.4
# 419   UC Browser Mini -Tiny Fast Private & Secure    COMMUNICATION     4.4
# 3237                               Motorola Alert            TOOLS     4.2
# 4685   HD Video Downloader : 2018 Best video mate    VIDEO_PLAYERS     3.7
# 3298                  Brightest Flashlight Free ®            TOOLS     4.7
# 3428                      Koi Free Live Wallpaper  PERSONALIZATION     4.2
# 4517                               QR Code Reader            TOOLS     4.0
# 4107                Video Downloader for Facebook            TOOLS     4.6
# 3484                         Advanced Task Killer     PRODUCTIVITY     4.4
#
# ...

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Top 10 Apps with Size less than 5MB According to number of installs

# %% [markdown]
# # Observation-16

# %%
top_genres = data.Genres.value_counts().reset_index().rename(columns={'Genres':'Count','index':'Genres'})
genres_installs = data.groupby(['Genres'])['Installs'].sum()
top_genres_installs = pd.merge(top_genres,genres_installs, on = "Genres")
top_20_genres_installs = top_genres_installs.head(20)

# %%
plt.figure(figsize=(14,7))
plt.xticks(rotation=75)
plt.xlabel("Genres")
plt.ylabel("Number of application")
plt.title("top 20 Genres")
sns.barplot(top_20_genres_installs.Genres, top_20_genres_installs.Count , palette=["#4285f4","#ea4335","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853"])
plt.show()

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Tools genres has the highest number of apps among all.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9144 entries, 0 to 9143
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   App                  7263 non-null   object
#  1   Category             7263 non-null   object
#  2   Rating               7263 non-null   float64
#  3   Reviews              7263 non-null   float64
#  4   Size                 7263 non-null   float64
#  5   Installs             7263 non-null   float64
#  6   Type                 7263 non-null   object
#  7   Price                7263 non-null   float64
#  8   Content Rating       7263 non-null   object
#  9   Genres               7263 non-null   object
#  10  Last Updated         7263 non-null   object
#  11  Android Ver          7263 non-null   object
#  12  Reviews*Rating       7263 non-null   float64
#  13  Reviews/Installs     7254 non-null   float64
#  14  Gaming category app  9144 non-null   bool
# ...

# %% [markdown]
# # Observation -17

# %%
data["Last Updated"].isnull().sum()
# Out:
# 1881

# %%
data['Last Updated'].fillna("not year")
# Out:
# 0        January 7, 2018
# 1       January 15, 2018
# 2         August 1, 2018
# 3           June 8, 2018
# 4          June 20, 2018
#               ...
# 9139       July 31, 2018
# 9140       July 24, 2017
# 9141        May 21, 2018
# 9142       July 24, 2018
# 9143        July 2, 2018
# Name: Last Updated, Length: 9144, dtype: object

# %%
data
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 9139                                        DZ Register    PRODUCTIVITY
# 9140                                     EA SPORTS UFC®          SPORTS
# 9141                         NBA LIVE Mobile Basketball          SPORTS
# 9142                          Need for Speed™ No Limits            GAME
# 9143                                      Real Racing 3          FAMILY
#
#       Rating    Reviews        Size    Installs  Type  Price Content Rating  \
# ...

# %%
data['year']=data['Last Updated'].apply(lambda x:str(x).split(",")[-1])

# %%
data
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 9139                                        DZ Register    PRODUCTIVITY
# 9140                                     EA SPORTS UFC®          SPORTS
# 9141                         NBA LIVE Mobile Basketball          SPORTS
# 9142                          Need for Speed™ No Limits            GAME
# 9143                                      Real Racing 3          FAMILY
#
#       Rating    Reviews        Size    Installs  Type  Price Content Rating  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.countplot(data['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
data.groupby('year')['year'].count()
# Out:
# year
#  2010       1
#  2011      12
#  2012      18
#  2013      79
#  2014     143
#  2015     340
#  2016     561
#  2017    1356
#  2018    4753
# nan      1881
# Name: year, dtype: int64

# %%
4755/9144
# Out:
# 0.52001312335958

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ###  52% of Apps are  last updated in 2018

# %% [markdown]
# # Observation -18

# %%
data.groupby('Category')['Content Rating'].count()
# Out:
# Category
# ART_AND_DESIGN           62
# AUTO_AND_VEHICLES        64
# BEAUTY                   44
# BOOKS_AND_REFERENCE     151
# BUSINESS                277
# COMICS                   50
# COMMUNICATION           207
# DATING                  176
# EDUCATION                96
# ENTERTAINMENT            67
# EVENTS                   49
# FAMILY                 1382
# FINANCE                 236
# FOOD_AND_DRINK           93
# GAME                    835
# HEALTH_AND_FITNESS      217
# HOUSE_AND_HOME           57
# LIBRARIES_AND_DEMO       78
# LIFESTYLE               281
# MAPS_AND_NAVIGATION      89
# MEDICAL                 359
# NEWS_AND_MAGAZINES      170
# PARENTING                53
# PERSONALIZATION         291
# PHOTOGRAPHY             223
# PRODUCTIVITY            243
# SHOPPING                173
# SOCIAL                  154
# SPORTS                  190
# TOOLS                   596
# TRAVEL_AND_LOCAL        140
# VIDEO_PLAYERS           115
# ...

# %% [markdown]
# ### Here, I grouped all the Apps by their Parent Category

# %%
EducationalApps=[
"ART_AND_DESIGN",
"BOOKS_AND_REFERENCE",
"BUSINESS",
"EDUCATION",
"FINANCE",
"LIBRARIES_AND_DEMO",
"NEWS_AND_MAGAZINES",
"COMICS"
]

LifeStyleApps=[
"COMMUNICATION",
"DATING",	
"FAMILY",
"HOUSE_AND_HOME",	
"LIFESTYLE",	
"PARENTING",
"PERSONALIZATION",
"SOCIAL",
"BEAUTY"   
]

HealthRelatedApp=[ 
"FOOD_AND_DRINK",
"HEALTH_AND_FITNESS",
"MEDICAL"    
]

TraveRelatedApp=[
"AUTO_AND_VEHICLES",
"MAPS_AND_NAVIGATION",
"TRAVEL_AND_LOCAL"
]

HobbiesRelatedApps=[   
"ENTERTAINMENT",
"GAME",
"PHOTOGRAPHY",	
"SPORTS",	
"VIDEO_PLAYERS",
"SHOPPING"
]

GeneralApps=[
"EVENTS",
"PRODUCTIVITY",
"TOOLS",
"WEATHER"
]


AppFirstWord=[]



for i in data["Category"]:
    if i in EducationalApps:
        AppFirstWord.append("EducationalApp")
    elif i in LifeStyleApps:
        AppFirstWord.append("LifeStyleApp")
    elif i in HealthRelatedApp:
        AppFirstWord.append("HealthRelatedApp")
    elif i in TraveRelatedApp:
        AppFirstWord.append("TravelRelatedApp")
    elif i in HobbiesRelatedApps:
        AppFirstWord.append("HobbiesRelatedApp")
    elif i in GeneralApps:
        AppFirstWord.append("GeneralApp")

# %%
len(AppFirstWord)
# Out:
# 9144

# %%
plt.figure(figsize=(12,8))
sns.countplot(AppFirstWord , palette=["#4285f4","#ea4335","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853"])
# Out:
# <AxesSubplot:ylabel='count'>

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Parent Category = LifeStyleApps , has most number of Apps on Play Store
# ### After grouping into parent Categories we got some meaningfull insight:
# #### -> Most of the apps available on PlayStore  are related to LifeStyle category followed by OtherApps
# #### ->lowest number of Apps are of Travel Related App Category

# %% [markdown]
# LifeStyleApps Category contains this many Category

# %% [markdown]
# "COMMUNICATION",
# "DATING",
# "FAMILY",
# "HOUSE_AND_HOME",
# "LIFESTYLE",
# "PARENTING",
# "PERSONALIZATION",
# "SOCIAL",
# "BEAUTY"

# %% [markdown]
# # Observation -19

# %%
df=pd.crosstab(data['Category'] , data['Content Rating'])

# %%
df
# Out:
# Content Rating       Adults only 18+  Everyone  Everyone 10+  Mature 17+  \
# Category
# ART_AND_DESIGN                     0        58             1           0
# AUTO_AND_VEHICLES                  0        62             1           0
# BEAUTY                             0        37             2           3
# BOOKS_AND_REFERENCE                0       137             5           2
# BUSINESS                           0       269             1           1
# COMICS                             1        23             3           6
# COMMUNICATION                      0       181             0           6
# DATING                             0        17             0         149
# EDUCATION                          0        88             5           2
# ENTERTAINMENT                      0        26             2           5
# EVENTS                             0        43             2           0
# FAMILY                             0      1097            88          39
# ...

# %%
plt.figure(figsize=(12,8))
sns.countplot(data['Content Rating'] , palette=["#4285f4","#ea4335","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853","#fbbc05","#34a853"])
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='count'>

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### 1. Almost all Dating Apps are for age  17+

# %% [markdown]
# ### 2. 10 Dating Apps are for teenagers only¶

# %% [markdown]
# ### 3.  157 Family Apps are for teenagers only

# %%
data
# Out:
#                                                     App        Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                   Coloring book moana  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint  ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                 ...             ...
# 9139                                        DZ Register    PRODUCTIVITY
# 9140                                     EA SPORTS UFC®          SPORTS
# 9141                         NBA LIVE Mobile Basketball          SPORTS
# 9142                          Need for Speed™ No Limits            GAME
# 9143                                      Real Racing 3          FAMILY
#
#       Rating    Reviews        Size    Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# # Obsrevation-20

# %%
sns.lineplot(x=data["Installs"],y=data["Reviews"])
# Out:
# <AxesSubplot:xlabel='Installs', ylabel='Reviews'>

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### Apps which has more number of Installs also has more number of Reviews

# %% [markdown]
# # Observation -21

# %%
sns.histplot(data['Price'] , bins=np.arange(1,400,5))
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %% [markdown]
# # conclusion:

# %% [markdown]
# # price of paid apps ranges between 0 to 50 USD

# %%
sns.boxplot(data['Price'])
# Out:
# <AxesSubplot:xlabel='Price'>

# %% [markdown]
# # Observation -22

# %%
sns.distplot(data['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.histplot(data['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %% [markdown]
# ### price features has a lot of outliers and it followes right skewed distribution

# %% [markdown]
# # conclusion:

# %% [markdown]
# ## As per the above plot , we can clearly se that the prices are commonly between 0 to 50 USD
